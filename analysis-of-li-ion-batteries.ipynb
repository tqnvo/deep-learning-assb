# %% [markdown]
# <a href="https://www.kaggle.com/tuanvqn/analysis-of-li-ion-batteries?scriptVersionId=89430526" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
batt_filepath = '../input/crystal-system-properties-for-liion-batteries/lithium-ion batteries.csv'

batt_data = pd.read_csv(batt_filepath, index_col='Materials Id')

# %%
#batt_data

# %%
#batt_data.head()

# %%
#batt_data.tail()

# %%
#batt_data.groupby('Formula').Formula.count()

# %%
#batt_data.groupby('Nsites').Nsites.count()

# %%
#batt_data_grouped = batt_data.groupby('Materials Id').Nsites.count()

# %%
#plt.figure(figsize=(20,5))
sns.swarmplot(x=batt_data['Crystal System'],
              y=batt_data['E Above Hull (eV)'])
plt.legend()

# %%
#plt.figure(figsize=(20,5))
sns.swarmplot(x=batt_data['Crystal System'],
              y=batt_data['Nsites'])
plt.legend()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/categorical.py:1296: UserWarning: 20.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/seaborn/categorical.py:1296: UserWarning: 12.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
#plt.figure(figsize=(20,5))
sns.swarmplot(x=batt_data['Has Bandstructure'],
              y=batt_data['Nsites'])
plt.legend()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/categorical.py:1296: UserWarning: 28.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
#plt.figure(figsize=(20,5))
sns.swarmplot(x=batt_data['Has Bandstructure'],
              y=batt_data['Volume'])
plt.legend()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/categorical.py:1296: UserWarning: 21.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
#plt.figure(figsize=(20,5))
sns.swarmplot(x=batt_data['Has Bandstructure'],
              y=batt_data['Density (gm/cc)'])
plt.legend()

# %%
#plt.figure(figsize=(20,5))
sns.swarmplot(x=batt_data['Has Bandstructure'],
              y=batt_data['Band Gap (eV)'])
plt.legend()

# %%
#plt.figure(figsize=(20,5))
sns.swarmplot(x=batt_data['Has Bandstructure'],
              y=batt_data['E Above Hull (eV)'])
plt.legend()

# %%
#plt.figure(figsize=(20,5))
sns.swarmplot(x=batt_data['Has Bandstructure'],
              y=batt_data['Formation Energy (eV)'])
plt.legend()

# %%
plt.figure(figsize=(30,5))
sns.lineplot(x=batt_data['Spacegroup'], y=batt_data['E Above Hull (eV)'], label='E Above Hull (eV)')
plt.legend()

# %%
plt.figure(figsize=(30,5))
sns.lineplot(x=batt_data['Spacegroup'], y=batt_data['Band Gap (eV)'], label='Band Gap (eV)')
plt.legend()

# %%
sns.distplot(a=batt_data['Formation Energy (eV)'], kde=False)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Formation Energy (eV)'>

# %%
sns.kdeplot(data=batt_data['Volume'], shade=True)
# Out:
# <AxesSubplot:xlabel='Volume', ylabel='Density'>

# %%
sns.jointplot(x=batt_data['Volume'], 
              y=batt_data['Band Gap (eV)'], kind="kde")

# %%
sns.jointplot(x=batt_data['E Above Hull (eV)'], 
              y=batt_data['Band Gap (eV)'], kind="kde")

# %%
sns.scatterplot(x=batt_data['Nsites'], 
                y=batt_data['Volume'])
# Out:
# <AxesSubplot:xlabel='Nsites', ylabel='Volume'>

# %%
sns.regplot(x=batt_data['Nsites'], 
                y=batt_data['Volume'])
# Out:
# <AxesSubplot:xlabel='Nsites', ylabel='Volume'>

# %%
sns.lmplot(x='Nsites', 
           y='Volume',
           hue="Has Bandstructure", 
           data=batt_data)

# %%
sns.regplot(x=batt_data['Density (gm/cc)'], 
            y=batt_data['Volume'])
# Out:
# <AxesSubplot:xlabel='Density (gm/cc)', ylabel='Volume'>

# %%
sns.lmplot(x='Density (gm/cc)', 
           y='Volume',
           hue="Has Bandstructure", 
           data=batt_data)

# %%
sns.scatterplot(x=batt_data['Nsites'], 
            y=batt_data['Volume'],
            hue=batt_data['Has Bandstructure'] )
# Out:
# <AxesSubplot:xlabel='Nsites', ylabel='Volume'>

# %%
sns.scatterplot(x=batt_data['Nsites'], 
            y=batt_data['Volume'],
            hue=batt_data['Crystal System'])
# Out:
# <AxesSubplot:xlabel='Nsites', ylabel='Volume'>

# %%
# Selection
#batt_selected = batt_data.loc[:, ['Formation Energy (eV)', 'Band Gap (eV)', 'Density (gm/cc)']]
batt_selected = batt_data.loc[:, ['Formation Energy (eV)']]

# %%
batt_data.index.value_counts()
batt_data['Crystal System'].value_counts()
batt_data['Spacegroup'].value_counts()
batt_data['Formula'].value_counts()
# Out:
# LiFeSiO4           42
# LiCoSiO4           29
# Li2FeSiO4          15
# Li2CoSiO4          14
# Li2MnSiO4          12
#                    ..
# Li3Co2Si3O10        1
# Li10Co(SiO5)2       1
# Li4Co2Si3O10        1
# Li2FeSi4O11         1
# Li5Co4(Si3O10)2     1
# Name: Formula, Length: 114, dtype: int64

# %%
sns.heatmap(data=batt_selected, annot=True)
# Out:
# <AxesSubplot:ylabel='Materials Id'>

# %%
batt_selected.head()
# Out:
#               Formation Energy (eV)
# Materials Id
# mp-849394                    -2.699
# mp-783909                    -2.696
# mp-761311                    -2.775
# mp-761598                    -2.783
# mp-767709                    -2.747

# %%
#batt_data.columns
batt_data.head()
# Out:
#                    Formula Spacegroup  Formation Energy (eV)  \
# Materials Id
# mp-849394        Li2MnSiO4         Pc                 -2.699
# mp-783909        Li2MnSiO4      P21/c                 -2.696
# mp-761311       Li4MnSi2O7         Cc                 -2.775
# mp-761598     Li4Mn2Si3O10       C2/c                 -2.783
# mp-767709     Li2Mn3Si3O10       C2/c                 -2.747
#
#               E Above Hull (eV)  Band Gap (eV)  Nsites  Density (gm/cc)  \
# Materials Id
# mp-849394                 0.006          3.462      16            2.993
# mp-783909                 0.008          2.879      32            2.926
# mp-761311                 0.012          3.653      28            2.761
# mp-761598                 0.013          3.015      38            2.908
# mp-767709                 0.016          2.578      36            3.334
#
#                Volume  Has Bandstructure Crystal System
# Materials Id
# mp-849394     178.513               True     monoclinic
# ...
